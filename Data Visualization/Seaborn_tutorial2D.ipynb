# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Set property

# %%
sns.set(style="whitegrid")

# %% [markdown]
# # Line plot

# %%
df1=pd.DataFrame(dict(time=np.arange(100),value=np.random.randn(100)))
sns.relplot(x="time",y="value",kind="line",data=df1) 
plt.show()

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint",y="signal",kind="line",data=fmri)

# %%
sns.relplot(x="timepoint",y="signal",kind="line",ci=None,data=fmri)
# Out:
# c:\Users\jayak\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x="timepoint",y="signal",kind="line",ci="sd",data=fmri)
# Out:
# c:\Users\jayak\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x="timepoint",y="signal",kind="line",estimator=None,ci="sd",data=fmri)
# Out:
# c:\Users\jayak\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x="timepoint",y="signal",hue="event",kind="line",ci="sd",data=fmri)
# Out:
# c:\Users\jayak\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# # Scatter plot

# %%
#sns.set(style="darkgrid")   to set a grid
sns.relplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",hue="smoker",data=df) #hue of spliting based on category
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",hue="smoker",style="time",data=df)
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",hue="smoker",size="size",data=df) # size- size of that data point
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",hue="time",data=df)
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",hue="day",style="time",data=df)
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",hue="day",style="time",size="size",data=df)
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",hue="day",size="size",palette="YlGnBu",data=df)
plt.show()

# %%
ax=sns.scatterplot(x="total_bill",y="tip",s=100,color=".2",marker="+",data=df)
plt.show()

# %%
iris=sns.load_dataset("iris")

# %%
sns.scatterplot(x=iris.sepal_length,y=iris.sepal_width,hue=iris.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Histogram

# %%
sns.histplot(df['tip'],kde=True,bins=5)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df['tip'],kde=True,bins=15) #no of division that the data needs to be classified
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(df['tip'],kde=True,bins=15)

# %% [markdown]
# # Bar plot

# %%
sns.barplot(x="sex",y="tip",data=df,palette="YlGnBu")
# Out:
# C:\Users\jayak\AppData\Local\Temp\ipykernel_20212\3572958588.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex",y="tip",data=df,palette="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(y="tip",data=df,palette="YlGnBu")
# Out:
# C:\Users\jayak\AppData\Local\Temp\ipykernel_20212\506696552.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="tip",data=df,palette="YlGnBu")
# <Axes: ylabel='tip'>

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x="sex",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x="day",y="tip",data=df,hue="sex",palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day",y="tip",data=df,hue="sex",palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.catplot(x="day",y="tip",data=df,hue="sex",palette="YlGnBu")

# %%
sns.stripplot(x="day",y="tip",data=df,hue="sex",palette="YlGnBu", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x="day",y="tip",data=df)

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="reg") #kind=regression

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="kde")

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="kde",fill=True)

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="hex")

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df.select_dtypes(["number"]), hue="size")

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
col=["Survived","Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]

# %%
sns.pairplot(titanic.select_dtypes(["number"]), hue="pclass")

# %% [markdown]
# # Heatmap

# %%
import numpy as np
data = np.random.randint(low = 1, 
                         high = 100, 
                         size = (10, 10)) 
print("The data to be plotted:\n") 
print(data) 
  
hm = sns.heatmap(data = data) 
plt.show()
# Out:
# The data to be plotted:
#
# [[46 45 11  5 77 58 76 31 97 98]
#  [15 84 90 37 54 25 10 19 24 59]
#  [28 45 30 55  6 37 46 39 24  1]
#  [88 23 76 10 32 76 50 52  6 83]
#  [33  2  1 21 88 25 30 68 43 37]
#  [55 23 53 34 61 32 86 58 33 79]
#  [93 27 98 88 52 69 42 29 94 75]
#  [28 18 17 57 30 27 18 72 23 16]
#  [28 73 53 63 27 47 83 10 81 78]
#  [ 5 85 11 64 97 34  6 21 11 89]]

# %%
hm = sns.heatmap(data = data,annot=True) 
plt.show()

# %% [markdown]
# # Lmplot

# %%
iris=sns.load_dataset("iris")

# %%
sns.lmplot(x="petal_length",y="petal_width",hue="species",data=iris,markers=["*","o","^"])

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x="day",y="tip",data=df)
plt.show()

# %%
g=["#A833FF","#FFAF33"]
sns.swarmplot(x="day",y="tip",data=df,hue="sex",palette=g)
plt.show()

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x=df["tip"],color="gold")
plt.show()

# %%
sns.violinplot(x="sex",y="total_bill",data=df)
plt.show()

# %% [markdown]
# # FaceGrid

# %%
f=sns.FacetGrid(df,col="time",row="sex")
f=f.map(plt.hist,"tip",color="tomato")

# %%
f=sns.FacetGrid(df,col="time",row="sex")
f=f.map(plt.scatter,"total_bill","tip",color="floralwhite",edgecolor="hotpink")

# %%
x=sns.FacetGrid(df,col="time",hue="sex")
x=x.map(plt.scatter,"total_bill","tip")
x=x.add_legend()

# %% [markdown]
# # Rug plot

# %%
sns.kdeplot(data=df, x="tip")
sns.rugplot(data=df, x="tip")
plt.show()

# %%
sns.scatterplot(data=df, x="total_bill", y="tip", hue="time")
sns.rugplot(data=df, x="total_bill", y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Probability Density function

# %%
sns.kdeplot(data=df, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Pie Chart
#  No pie chart in seaborn use matplotlib

# %% [markdown]
# # Area chart

# %%
  
data = {'period': [1, 2, 3, 4, 5, 6, 7, 8], 
                   'team_B': [15, 17, 17, 19, 22, 19, 19, 14], 
                   'team_C': [21, 18, 20, 16, 16, 15, 19, 22]} 
  
# define DataFrame 
df = pd.DataFrame(data) 
  
# define colors to use in chart 
color_map = ['orange', 'pink'] 
  
#create area chart 
plt.stackplot(df.period, df.team_B, df.team_C, 
              labels=['Team B', 'Team C'], 
              colors=color_map)

# %%
df = pd.DataFrame({'Class': [1, 2, 3, 4, 5, 6, 7, 8], 
                   'sec_A': [20, 12, 9, 14, 18, 20, 15, 22], 
                   'sec_B': [ 12, 5, 7, 7, 9, 9, 9, 4], 
                   'sec_C': [11, 8, 5, 9, 12, 10, 6, 6]}) 
  
# define colors to use in chart 
color_map = ['yellow', 'blue', 'black'] 
  
# create area chart 
plt.stackplot(df.Class, df.sec_A, df.sec_B, df.sec_C, 
              labels=['Sec A', 'Sec B', 'Sec C'], 
              colors=color_map)
